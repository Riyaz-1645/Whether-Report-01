# %% [markdown]
# <a href="https://colab.research.google.com/github/Riyaz-1645/Whether-Report-01/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
def quadratic_temperature_model(time,a,b,c):
  temperature=(a*(time*time))+(b*time)+c
  return (temperature)

a=int(input("enter coefficient for quadratic term"))
b=int(input("enter coefficient for linear term"))
c=int(input("enter constant value"))
time_values=np.arange(0,51,1)

temperature_values=quadratic_temperature_model(time_values,a,b,c)


plt.plot(time_values, temperature_values, label='Temperature model')
plt.xlabel('time')
plt.ylabel('temperature')
plt.title("quadratic temperature model")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# enter coefficient for quadratic term5
# enter coefficient for linear term2
# enter constant value4

# %%
import matplotlib.pyplot as plt
import numpy as np
def quadratic_model(time):
  a=0.1
  b=-1
  c=30
  temperature=(a*(time*time))+(b*time)+c
  return (temperature)


time_values = np.linspace(0,10,100)
temperature_hardcoded = quadratic_model(time_values)

plt.plot(time_values, temperature_hardcoded, label='Hard-coded coefficients')
plt.xlabel('time')
plt.ylabel('temperature')
plt.legend()
plt.title("Weather modeling with quadratic equation")
plt.show()

# %%
import matplotlib.pyplot as plt

def quadratic_temperature_model(time_values, a, b, c):
    # Your quadratic equation implementation here
    temperature_values = [a * (t**2) + b * t + c for t in time_values]
    return temperature_values

# Example coefficients_list
coefficients_list = [(1, 2, 4), (-1, 0, 1), (3, -1, 1)]

# Plotting for multiple sets of coefficients
for i, (a, b, c) in enumerate(coefficients_list):
    time_values = range(10)  # Adjust this based on your time values

    temperature_values = quadratic_temperature_model(time_values, a, b, c)

    plt.plot(time_values, temperature_values, label=f'Set {i + 1}: a={a}, b={b}, c={c}')

plt.xlabel('Time')
plt.ylabel('Temperature')
plt.title("Quadratic Temperature Model with Multiple Sets of Coefficients")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# hard code variables
def quadratic_model(a,b,c,time):
  temperature = a*time*time + b*time + c
  return temperature

time_values=np.linspace(0,10,100)

a=2
b=4
c=9
x=int(input("Enter value of a : "))
y=int(input("Enter value of b : "))
z=int(input("Enter value of c : "))
temperature_hardcoded = quadratic_model(a,b,c,time_values)
temperature = quadratic_model(x,y,z,time_values)
plt.plot(time_values,temperature_hardcoded, label='temperature with hard coded coefficients')
plt.plot(time_values,temperature, label='temperature')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.legend()
plt.title('weather modeling with quadratic equation(Hard-coded coefficient)')
plt.show()
# Out:
# Enter value of a : 5
# Enter value of b : 6
# Enter value of c : 9

# %%
f = open("weather.txt", "r")

import matplotlib.pyplot as plt
import numpy as np
# hard code variables
def quadratic_model(f,time):
  a=int(f.readline())
  b=int(f.readline())
  c=int(f.readline())
  temperature = a*time*time + b*time + c
  return temperature

time_values=np.linspace(0,10,50)
temperature_hardcoded = quadratic_model(f,time_values)

plt.plot(time_values,temperature_hardcoded, label='temperature with hard coded coefficients')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.legend()
plt.title('weather modeling with quadratic equation(read from file)')
plt.show()
